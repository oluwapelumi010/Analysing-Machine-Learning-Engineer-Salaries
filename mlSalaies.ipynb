# %%
import pandas as pd
df = pd.read_csv('salaries.csv')
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df['experience_level'].value_counts()
# Out:
# experience_level
# SE    10652
# MI     4024
# EN     1319
# EX      499
# Name: count, dtype: int64

# %%
df['company_location'].value_counts()
# Out:
# company_location
# US    14478
# GB      694
# CA      455
# ES      133
# DE      105
#       ...
# AM        1
# QA        1
# AD        1
# EC        1
# MD        1
# Name: count, Length: 77, dtype: int64

# %%
location = df['company_location'].str.contains('US')
df.loc[location,'job_title']
# Out:
# 2                        Data Scientist
# 3                        Data Scientist
# 4                  Data Science Manager
# 5                  Data Science Manager
# 6        Business Intelligence Engineer
#                       ...
# 16488                   Data Specialist
# 16489                    Data Scientist
# 16490          Principal Data Scientist
# 16491                    Data Scientist
# 16492             Business Data Analyst
# Name: job_title, Length: 14478, dtype: object

# %%
to_find = ['Data Scientist']
filt = df['job_title'].isin(to_find)
df.loc[filt]
# Out:
#        work_year experience_level employment_type       job_title  salary  \
# 0           2024               MI              FT  Data Scientist  120000
# 1           2024               MI              FT  Data Scientist   70000
# 2           2024               MI              CT  Data Scientist  130000
# 3           2024               MI              CT  Data Scientist  110000
# 16          2024               SE              FT  Data Scientist  138000
# ...          ...              ...             ...             ...     ...
# 16480       2020               MI              FT  Data Scientist  118000
# 16481       2020               MI              FT  Data Scientist  138350
# 16485       2021               MI              FT  Data Scientist  160000
# 16489       2020               SE              FT  Data Scientist  412000
# 16491       2020               EN              FT  Data Scientist  105000
#
#       salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
fav = df['salary_in_usd'] >= 110000
df.loc[fav,['work_year', 'experience_level', 'employment_type', 'job_title',
       'salary']]
# Out:
#        work_year experience_level employment_type  \
# 0           2024               MI              FT
# 2           2024               MI              CT
# 3           2024               MI              CT
# 4           2024               MI              FT
# 5           2024               MI              FT
# ...          ...              ...             ...
# 16485       2021               MI              FT
# 16486       2021               MI              FT
# 16488       2021               SE              FT
# 16489       2020               SE              FT
# 16490       2021               MI              FT
#
#                                 job_title  salary
# 0                          Data Scientist  120000
# 2                          Data Scientist  130000
# 3                          Data Scientist  110000
# 4                    Data Science Manager  240000
# 5                    Data Science Manager  180000
# ...                                   ...     ...
# ...

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data Engineer                    3456
# Data Scientist                   3312
# Data Analyst                     2428
# Machine Learning Engineer        1703
# Research Scientist                529
#                                  ...
# Quantitative Research Analyst       1
# AWS Data Architect                  1
# Analytics Engineering Manager       1
# Marketing Data Scientist            1
# Data Analytics Associate            1
# Name: count, Length: 155, dtype: int64

# %%
df.rename(columns={'salary':'salary_in_usd'})
df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.sort_values(by=['work_year','experience_level'], ascending=[True,False])
df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.mean
# Out:
# <bound method DataFrame.mean of        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.head(2)
# Out:
#    work_year experience_level employment_type       job_title  salary_in_usd  \
# 0       2024               MI              FT  Data Scientist         120000
# 1       2024               MI              FT  Data Scientist          70000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         120000                 AU             0
# 1             USD          70000                 AU             0
#
#   company_location company_size
# 0               AU            S
# 1               AU            S

# %%
df['salary_in_usd'].median()
# Out:
# salary_in_usd    142200.0
# salary_in_usd    141300.0
# dtype: float64

# %%
df['salary_in_usd'].mean()
# Out:
# salary_in_usd    163787.809628
# salary_in_usd    149713.575725
# dtype: float64

# %%
df.describe()
# Out:
#           work_year  salary_in_usd  salary_in_usd  remote_ratio
# count  16494.000000   1.649400e+04   16494.000000  16494.000000
# mean    2023.224991   1.637878e+05  149713.575725     32.044986
# std        0.713405   3.406017e+05   68516.136918     46.260201
# min     2020.000000   1.400000e+04   15000.000000      0.000000
# 25%     2023.000000   1.020000e+05  101517.500000      0.000000
# 50%     2023.000000   1.422000e+05  141300.000000      0.000000
# 75%     2024.000000   1.873422e+05  185900.000000    100.000000
# max     2024.000000   3.040000e+07  800000.000000    100.000000

# %%
job_grouped = df.groupby(['job_title'])
job_grouped.get_group('Data Scientist')
# Out:
# C:\Users\AYOMIDE PC\AppData\Local\Temp\ipykernel_6276\1104693752.py:2: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   job_grouped.get_group('Data Scientist')
#        work_year experience_level employment_type       job_title  \
# 0           2024               MI              FT  Data Scientist
# 1           2024               MI              FT  Data Scientist
# 2           2024               MI              CT  Data Scientist
# 3           2024               MI              CT  Data Scientist
# 16          2024               SE              FT  Data Scientist
# ...          ...              ...             ...             ...
# 16480       2020               MI              FT  Data Scientist
# 16481       2020               MI              FT  Data Scientist
# 16485       2021               MI              FT  Data Scientist
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type             job_title  \
# 0       2024               MI              FT        Data Scientist
# 1       2024               MI              FT        Data Scientist
# 2       2024               MI              CT        Data Scientist
# 3       2024               MI              CT        Data Scientist
# 4       2024               MI              FT  Data Science Manager
#
#    salary_in_usd salary_currency  salary_in_usd employee_residence  \
# 0         120000             USD         120000                 AU
# 1          70000             USD          70000                 AU
# 2         130000             USD         130000                 US
# 3         110000             USD         110000                 US
# 4         240000             USD         240000                 US
#
#    remote_ratio company_location company_size
# 0             0               AU            S
# 1             0               AU            S
# ...

# %%
to_filt = df['job_title'] == 'Data Scientist'
df.loc[to_filt]['salary_in_usd']
# Out:
#        salary_in_usd  salary_in_usd
# 0             120000         120000
# 1              70000          70000
# 2             130000         130000
# 3             110000         110000
# 16            138000         138000
# ...              ...            ...
# 16480         118000         118000
# 16481         138350         138350
# 16485         160000         119059
# 16489         412000         412000
# 16491         105000         105000
#
# [3312 rows x 2 columns]

# %%
job_grouped['salary_in_usd'].value_counts().head(100)
# Out:
# job_title     salary_in_usd  salary_in_usd
# AI Architect  204000         204000           4
#               330000         330000           4
#               99750          99750            1
#               132500         132500           1
#               137000         137000           1
#                                              ..
# AI Engineer   180500         180500           1
#               186754         186754           1
#               195000         195000           1
#               200070         200070           1
#               223000         223000           1
# Name: count, Length: 100, dtype: int64

# %%
job_grouped['salary_in_usd'].value_counts()
# Out:
# job_title                        salary_in_usd  salary_in_usd
# AI Architect                     204000         204000           4
#                                  330000         330000           4
#                                  99750          99750            1
#                                  132500         132500           1
#                                  137000         137000           1
#                                                                 ..
# Staff Data Analyst               60000          44753            1
#                                  179998         179998           1
# Staff Data Scientist             105000         105000           1
#                                  164000         164000           1
# Staff Machine Learning Engineer  185000         185000           1
# Name: count, Length: 6480, dtype: int64
